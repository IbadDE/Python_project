# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests

# %%
                                          # Islamabad United team in 2016

url = 'https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/islamabad-united-squad-967313/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_isl = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_isl))


data_16 = []

for player in player_profile_isl:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Islamabad United'
    season = "2015/2016"
    data_16.append([season,team,name, role] + bowl_bat)





                                          # Karachi Kings team in 2016

url = 'https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/karachi-kings-squad-967331/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_kar = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_kar))

for player in player_profile_kar:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Karachi Kings'
    season = "2015/2016"
    data_16.append([season,team,name, role] + bowl_bat)

    
    
    
    

                                        # lahore Qalanders team in 2016

url = 'https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/lahore-qalandars-squad-967333/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_lhr = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_lhr))

for player in player_profile_lhr:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Lahore Qalandars'
    season = "2015/2016"
    data_16.append([season,team,name, role] + bowl_bat)



    

                                        # Pesahwar Zalmi team in 2016

url = 'https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/peshawar-zalmi-squad-967335/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_pes = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_pes))

for player in player_profile_pes:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Peshawar Zalmi'
    season = "2015/2016"
    data_16.append([season,team,name, role] + bowl_bat)





                            # Quetta Gladiators Zalmi team in 2016

url = 'https://www.espncricinfo.com/series/pakistan-super-league-2015-16-923069/quetta-gladiators-squad-967339/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_que = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_que))

for player in player_profile_que:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Quetta Gladiators'
    season = "2015/2016"
    data_16.append([season,team,name, role] + bowl_bat)
    

df_16 = pd.DataFrame(data_16)
print(df_16.shape)
df_16.head()
# Out:
# 16
# 16
# 16
# 19
# 16
# (83, 7)
#            0                 1              2                    3  \
# 0  2015/2016  Islamabad United      Amad Butt   Bowling Allrounder
# 1  2015/2016  Islamabad United     Babar Azam               Batter
# 2  2015/2016  Islamabad United  Samuel Badree               Bowler
# 3  2015/2016  Islamabad United  Sam Billings†  Wicketkeeper Batter
# 4  2015/2016  Islamabad United   Brad Haddin†  Wicketkeeper Batter
#
#                4                        5                            6
# 0  Age: 20y 226d  Batting: Right hand Bat      Bowling: Right arm Fast
# 1   Age: 21y 68d  Batting: Right hand Bat  Bowling: Right arm Offbreak
# 2  Age: 34y 288d  Batting: Right hand Bat            Bowling: Legbreak
# 3  Age: 24y 190d  Batting: Right hand Bat                         None
# 4   Age: 38y 60d  Batting: Right hand Bat                         None

# %%
                                          # Islamabad United team in 2017

url = 'https://www.espncricinfo.com/series/psl-2016-17-1075974/islamabad-united-squad-1081266/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_isl = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_isl))


data_17 = []

for player in player_profile_isl:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Islamabad United'
    season = "2016/2017"
    data_17.append([season,team,name, role] + bowl_bat)





                                          # Karachi Kings team in 2017

url = 'https://www.espncricinfo.com/series/psl-2016-17-1075974/karachi-kings-squad-1081267/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_kar = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_kar))

for player in player_profile_kar:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Karachi Kings'
    season = "2016/2017"
    data_17.append([season,team,name, role] + bowl_bat)

    
    
    
    
    
    

                                        # lahore Qalanders team in 2017

url = 'https://www.espncricinfo.com/series/psl-2016-17-1075974/lahore-qalandars-squad-1081274/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_lhr = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_lhr))

for player in player_profile_lhr:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Lahore Qalandars'
    season = "2016/2017"
    data_17.append([season,team,name, role] + bowl_bat)



    
                                    # Pesahwar Zalmi team in 2017

url = 'https://www.espncricinfo.com/series/psl-2016-17-1075974/peshawar-zalmi-squad-1081269/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_pes = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_pes))

for player in player_profile_pes:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Peshawar Zalmi'
    season = "2016/2017"
    data_17.append([season,team,name, role] + bowl_bat)





                                    # Quetta Gladiators Zalmi team in 2017

url = 'https://www.espncricinfo.com/series/psl-2016-17-1075974/quetta-gladiators-squad-1081272/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_que = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_que))

for player in player_profile_que:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Quetta Gladiators'
    season = "2016/2017"
    data_17.append([season,team,name, role] + bowl_bat)



df_17 = pd.DataFrame(data_17)
print(df_17.shape)
df_17.head()
# Out:
# 21
# 20
# 20
# 21
# 20
# (102, 7)
#            0                 1                 2                    3  \
# 0  2016/2017  Islamabad United  Misbah-ul-Haq(c)  Middle order Batter
# 1  2016/2017  Islamabad United         Amad Butt   Bowling Allrounder
# 2  2016/2017  Islamabad United          Asif Ali  Middle order Batter
# 3  2016/2017  Islamabad United     Samuel Badree               Bowler
# 4  2016/2017  Islamabad United     Sam Billings†  Wicketkeeper Batter
#
#                4                        5                            6
# 0  Age: 42y 240d  Batting: Right hand Bat            Bowling: Legbreak
# 1  Age: 21y 258d  Batting: Right hand Bat      Bowling: Right arm Fast
# 2  Age: 25y 114d  Batting: Right hand Bat  Bowling: Right arm Offbreak
# 3  Age: 35y 320d  Batting: Right hand Bat            Bowling: Legbreak
# 4  Age: 25y 222d  Batting: Right hand Bat                         None

# %%
                                          # Islamabad United team in 2018

url = 'https://www.espncricinfo.com/series/psl-2017-18-1128817/islamabad-united-squad-1137265/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_isl = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_isl))


data_18 = []

for player in player_profile_isl:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Islamabad United'
    season = "2017/2018"
    data_18.append([season,team,name, role] + bowl_bat)





                                          # Karachi Kings team in 2018

url = 'https://www.espncricinfo.com/series/psl-2017-18-1128817/karachi-kings-squad-1137263/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_kar = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_kar))

for player in player_profile_kar:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Karachi Kings'
    season = "2017/2018"
    data_18.append([season,team,name, role] + bowl_bat)

    
    
    

                                    # lahore Qalanders team in 2018

url = 'https://www.espncricinfo.com/series/psl-2017-18-1128817/lahore-qalandars-squad-1137236/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_lhr = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_lhr))

for player in player_profile_lhr:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Lahore Qalandars'
    season = "2017/2018"
    data_18.append([season,team,name, role] + bowl_bat)




                                    # Pesahwar Zalmi team in 2018

url = 'https://www.espncricinfo.com/series/psl-2017-18-1128817/peshawar-zalmi-squad-1137290/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_pes = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_pes))

for player in player_profile_pes:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Peshawar Zalmi'
    season = "2017/2018"
    data_18.append([season,team,name, role] + bowl_bat)





                                        # Quetta Gladiators Zalmi team in 2018

url = 'https://www.espncricinfo.com/series/psl-2017-18-1128817/quetta-gladiators-squad-1137231/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_que = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_que))

for player in player_profile_que:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Quetta Gladiators'
    season = "2017/2018"
    data_18.append([season,team,name, role] + bowl_bat)
    
    
    
    
                                        # Multan Sultan Team in 2018
        
    
url = 'https://www.espncricinfo.com/series/psl-2017-18-1128817/quetta-gladiators-squad-1137231/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_mul = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_mul))

for player in player_profile_mul:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Multan Sultans'
    season = "2017/2018"
    data_18.append([season,team,name, role] + bowl_bat)



df_18 = pd.DataFrame(data_18)
print(df_18.shape)
df_18.head()
# Out:
# 22
# 20
# 22
# 27
# 19
# 19
# (129, 7)
#            0                 1                 2                    3  \
# 0  2017/2018  Islamabad United  Misbah-ul-Haq(c)  Middle order Batter
# 1  2017/2018  Islamabad United         Amad Butt   Bowling Allrounder
# 2  2017/2018  Islamabad United          Asif Ali  Middle order Batter
# 3  2017/2018  Islamabad United     Samuel Badree               Bowler
# 4  2017/2018  Islamabad United     Sam Billings†  Wicketkeeper Batter
#
#                4                        5                            6
# 0  Age: 43y 268d  Batting: Right hand Bat            Bowling: Legbreak
# 1  Age: 22y 286d  Batting: Right hand Bat      Bowling: Right arm Fast
# 2  Age: 26y 142d  Batting: Right hand Bat  Bowling: Right arm Offbreak
# 3  Age: 36y 348d  Batting: Right hand Bat            Bowling: Legbreak
# 4  Age: 26y 250d  Batting: Right hand Bat                         None

# %%
                                          # Islamabad United team in 2019

url = 'https://www.espncricinfo.com/series/psl-2018-19-1168814/islamabad-united-squad-1173965/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_isl = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_isl))


data_19 = []

for player in player_profile_isl:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Islamabad United'
    season = "2018/2019"
    data_19.append([season,team,name, role] + bowl_bat)





                                          # Karachi Kings team in 2019

url = 'https://www.espncricinfo.com/series/psl-2018-19-1168814/karachi-kings-squad-1173970/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_kar = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_kar))

for player in player_profile_kar:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Karachi Kings'
    season = "2018/2019"
    data_19.append([season,team,name, role] + bowl_bat)

    
    
    
    
    
    

                                        # lahore Qalanders team in 2019

url = 'https://www.espncricinfo.com/series/psl-2018-19-1168814/lahore-qalandars-squad-1173968/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_lhr = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_lhr))

for player in player_profile_lhr:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Lahore Qalandars'
    season = "2018/2019"
    data_19.append([season,team,name, role] + bowl_bat)




                                    # Pesahwar Zalmi team in 2019

url = 'https://www.espncricinfo.com/series/psl-2018-19-1168814/peshawar-zalmi-squad-1173977/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_pes = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_pes))

for player in player_profile_pes:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Peshawar Zalmi'
    season = "2018/2019"
    data_19.append([season,team,name, role] + bowl_bat)





                                    # Quetta Gladiators Zalmi team in 2019

url = 'https://www.espncricinfo.com/series/psl-2018-19-1168814/quetta-gladiators-squad-1173979/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_que = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_que))

for player in player_profile_que:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Quetta Gladiators'
    season = "2018/2019"
    data_19.append([season,team,name, role] + bowl_bat)
    
    
    
    
                                    # Multan Sultan Team in 2019
        
url = 'https://www.espncricinfo.com/series/psl-2018-19-1168814/multan-sultans-squad-1173975/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_mul = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_mul))

for player in player_profile_mul:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Multan Sultans'
    season = "2018/2019"
    data_19.append([season,team,name, role] + bowl_bat)



df_19 = pd.DataFrame(data_19)
print(df_19.shape)
df_19.head()
# Out:
# 20
# 21
# 23
# 20
# 23
# 25
# (132, 7)
#            0                 1                 2                    3  \
# 0  2018/2019  Islamabad United  Mohammad Sami(c)               Bowler
# 1  2018/2019  Islamabad United         Amad Butt   Bowling Allrounder
# 2  2018/2019  Islamabad United          Asif Ali  Middle order Batter
# 3  2018/2019  Islamabad United          Ian Bell     Top order Batter
# 4  2018/2019  Islamabad United   Cameron Delport     Top order Batter
#
#                4                        5                            6
# 0  Age: 37y 334d  Batting: Right hand Bat      Bowling: Right arm Fast
# 1  Age: 23y 259d  Batting: Right hand Bat      Bowling: Right arm Fast
# 2  Age: 27y 115d  Batting: Right hand Bat  Bowling: Right arm Offbreak
# 3  Age: 36y 288d  Batting: Right hand Bat    Bowling: Right arm Medium
# 4  Age: 29y 257d   Batting: Left hand Bat    Bowling: Right arm Medium

# %%
                                          # Islamabad United team in 2020

url = 'https://www.espncricinfo.com/series/psl-2019-20-2020-21-1211602/islamabad-united-squad-1215698/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_isl = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_isl))


data_20 = []

for player in player_profile_isl:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Islamabad United'
    season = "2019/2020"
    data_20.append([season,team,name, role] + bowl_bat)





                                          # Karachi Kings team in 2020

url = 'https://www.espncricinfo.com/series/psl-2019-20-2020-21-1211602/karachi-kings-squad-1215701/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_kar = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_kar))

for player in player_profile_kar:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Karachi Kings'
    season = "2019/2020"
    data_20.append([season,team,name, role] + bowl_bat)

    
    
    
    
    
    

                                        # lahore Qalanders team in 2020

url = 'https://www.espncricinfo.com/series/psl-2019-20-2020-21-1211602/lahore-qalandars-squad-1215702/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_lhr = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_lhr))

for player in player_profile_lhr:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Lahore Qalandars'
    season = "2019/2020"
    data_20.append([season,team,name, role] + bowl_bat)




                                    # Pesahwar Zalmi team in 2020

url = 'https://www.espncricinfo.com/series/psl-2019-20-2020-21-1211602/peshawar-zalmi-squad-1215706/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_pes = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_pes))

for player in player_profile_pes:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Peshawar Zalmi'
    season = "2019/2020"
    data_20.append([season,team,name, role] + bowl_bat)





                                    # Quetta Gladiators team in 2020

url = 'https://www.espncricinfo.com/series/psl-2019-20-2020-21-1211602/quetta-gladiators-squad-1215709/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_que = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_que))

for player in player_profile_que:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Quetta Gladiators'
    season = "2019/2020"
    data_20.append([season,team,name, role] + bowl_bat)
    
    
    
    
                                    # Multan Sultan Team in 2020
    
url = 'https://www.espncricinfo.com/series/psl-2019-20-2020-21-1211602/multan-sultans-squad-1215703/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_mul = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_mul))

for player in player_profile_mul:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Multan Sultans'
    season = "2019/2020"
    data_20.append([season,team,name, role] + bowl_bat)



df_20 = pd.DataFrame(data_20)
print(df_20.shape)
df_20.drop([7], axis = 1, inplace = True)
df_20.head()
# Out:
# 19
# 22
# 19
# 25
# 18
# 22
# (125, 8)
#            0                 1                    2                    3  \
# 0  2019/2020  Islamabad United       Shadab Khan(c)           Allrounder
# 1  2019/2020  Islamabad United  Ahmed Safi Abdullah   Bowling Allrounder
# 2  2019/2020  Islamabad United           Akif Javed               Bowler
# 3  2019/2020  Islamabad United            Amad Butt   Bowling Allrounder
# 4  2019/2020  Islamabad United             Asif Ali  Middle order Batter
#
#                4                        5                                6
# 0   Age: 21y 63d  Batting: Right hand Bat                Bowling: Legbreak
# 1  Age: 21y 280d   Batting: Left hand Bat  Bowling: Slow Left arm Orthodox
# 2   Age: 19y 57d  Batting: Right hand Bat    Bowling: Left arm Medium fast
# 3  Age: 24y 210d  Batting: Right hand Bat          Bowling: Right arm Fast
# 4   Age: 28y 66d  Batting: Right hand Bat      Bowling: Right arm Offbreak

# %%
                                          # Islamabad United team in 2021

url = 'https://www.espncricinfo.com/series/psl-2020-21-2021-1238103/islamabad-united-squad-1249785/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_isl = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_isl))


data_21 = []

for player in player_profile_isl:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Islamabad United'
    season = "2020/2021"
    data_21.append([season,team,name, role] + bowl_bat)




                                          # Karachi Kings team in 2021

url = 'https://www.espncricinfo.com/series/psl-2020-21-2021-1238103/karachi-kings-squad-1249786/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_kar = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_kar))

for player in player_profile_kar:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Karachi Kings'
    season = "2020/2021"
    data_21.append([season,team,name, role] + bowl_bat)

    
    

                                        # lahore Qalanders team in 2021

url = 'https://www.espncricinfo.com/series/psl-2020-21-2021-1238103/lahore-qalandars-squad-1249787/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_lhr = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_lhr))

for player in player_profile_lhr:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Lahore Qalandars'
    season = "2020/2021"
    data_21.append([season,team,name, role] + bowl_bat)




                                        # Pesahwar Zalmi team in 2021

url = 'https://www.espncricinfo.com/series/psl-2020-21-2021-1238103/peshawar-zalmi-squad-1249790/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_pes = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_pes))

for player in player_profile_pes:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Peshawar Zalmi'
    season = "2020/2021"
    data_21.append([season,team,name, role] + bowl_bat)




                                    # Quetta Gladiators Zalmi team in 2021

url = 'https://www.espncricinfo.com/series/psl-2020-21-2021-1238103/quetta-gladiators-squad-1249791/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_que = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_que))

for player in player_profile_que:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Quetta Gladiators'
    season = "2020/2021"
    data_21.append([season,team,name, role] + bowl_bat)
    
    
    
    
                                    # Multan Sultan Team in 2021
                
url = 'https://www.espncricinfo.com/series/psl-2020-21-2021-1238103/multan-sultans-squad-1249789/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_mul = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_mul))

for player in player_profile_mul:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Multan Sultans'
    season = "2020/2021"
    data_21.append([season,team,name, role] + bowl_bat)



df_21 = pd.DataFrame(data_21)
print(df_21.shape)
df_21.drop([7], axis = 1 , inplace = True)
df_21.head()
# Out:
# 27
# 23
# 26
# 28
# 26
# 28
# (158, 8)
#            0                 1                    2                    3  \
# 0  2020/2021  Islamabad United       Shadab Khan(c)           Allrounder
# 1  2020/2021  Islamabad United  Ahmed Safi Abdullah   Bowling Allrounder
# 2  2020/2021  Islamabad United           Akif Javed               Bowler
# 3  2020/2021  Islamabad United             Ali Khan               Bowler
# 4  2020/2021  Islamabad United             Asif Ali  Middle order Batter
#
#                4                        5                                6
# 0   Age: 22y 98d  Batting: Right hand Bat                Bowling: Legbreak
# 1  Age: 22y 315d   Batting: Left hand Bat  Bowling: Slow Left arm Orthodox
# 2   Age: 20y 92d  Batting: Right hand Bat    Bowling: Left arm Medium fast
# 3   Age: 30y 28d  Batting: Right hand Bat   Bowling: Right arm Fast medium
# 4  Age: 29y 101d  Batting: Right hand Bat      Bowling: Right arm Offbreak

# %%
                                          # Islamabad United team in 2022

url = 'https://www.espncricinfo.com/series/pakistan-super-league-2021-22-1292999/islamabad-united-squad-1293208/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_isl = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_isl))


data_22 = []

for player in player_profile_isl:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Islamabad United'
    season = "2021/2022"
    data_22.append([season,team,name, role] + bowl_bat)




                                          # Karachi Kings team in 2022

url = 'https://www.espncricinfo.com/series/pakistan-super-league-2021-22-1292999/karachi-kings-squad-1293210/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_kar = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_kar))

for player in player_profile_kar:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Karachi Kings'
    season = "2021/2022"
    data_22.append([season,team,name, role] + bowl_bat)

    
    
    
                                        # lahore Qalanders team in 2022

url = 'https://www.espncricinfo.com/series/pakistan-super-league-2021-22-1292999/lahore-qalandars-squad-1293211/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_lhr = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_lhr))

for player in player_profile_lhr:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Lahore Qalandars'
    season = "2021/2022"
    data_22.append([season,team,name, role] + bowl_bat)




                                        # Pesahwar Zalmi team in 2022
        
url = 'https://www.espncricinfo.com/series/pakistan-super-league-2021-22-1292999/peshawar-zalmi-squad-1293220/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_pes = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_pes))

for player in player_profile_pes:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Peshawar Zalmi'
    season = "2021/2022"
    data_22.append([season,team,name, role] + bowl_bat)





                                        # Quetta Gladiators Zalmi team in 2022

url = 'https://www.espncricinfo.com/series/pakistan-super-league-2021-22-1292999/quetta-gladiators-squad-1293221/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_que = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_que))

for player in player_profile_que:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Quetta Gladiators'
    season = "2021/2022"
    data_22.append([season,team,name, role] + bowl_bat)
    
    
    
    
                                        # Multan Sultan Team in 2022
    
url = 'https://www.espncricinfo.com/series/pakistan-super-league-2021-22-1292999/multan-sultans-squad-1293214/series-squads'
source = requests.get(url)
soup = bs(source.text, 'html.parser')
player_profile_mul = soup.find('div', class_ = 'ds-grid lg:ds-grid-cols-2').find_all('div', class_="ds-flex-1")
print(len(player_profile_mul))

for player in player_profile_mul:
    name = player.find('div', class_ = 'ds-flex ds-flex-row ds-items-center ds-space-x-2').text
    role = player.find('p', class_ = 'ds-text-tight-l ds-mb-2 ds-mt-1').text
    p_tag = player.find('div', class_ = 'ds-text-ui-typo-mid').find_all('p', class_ = 'ds-text-tight-m ds-font-regular')
    bowl_bat = [i.text for i in p_tag]
    team = 'Multan Sultans'
    season = "2021/2022"
    data_22.append([season,team,name, role] + bowl_bat)



df_22 = pd.DataFrame(data_22)
print(df_22.shape)
df_22.head()
# Out:
# 21
# 23
# 22
# 23
# 24
# 22
# (135, 7)
#            0                 1               2                    3  \
# 0  2021/2022  Islamabad United  Shadab Khan(c)           Allrounder
# 1  2021/2022  Islamabad United        Asif Ali  Middle order Batter
# 2  2021/2022  Islamabad United   Athar Mahmood               Bowler
# 3  2021/2022  Islamabad United      Azam Khan†         Wicketkeeper
# 4  2021/2022  Islamabad United     Danish Aziz           Allrounder
#
#                4                        5                                6
# 0   Age: 23y 69d  Batting: Right hand Bat                Bowling: Legbreak
# 1   Age: 30y 72d  Batting: Right hand Bat      Bowling: Right arm Offbreak
# 2  Age: 22y 170d  Batting: Right hand Bat   Bowling: Right arm Fast medium
# 3  Age: 23y 124d  Batting: Right hand Bat                             None
# 4   Age: 26y 22d   Batting: Left hand Bat  Bowling: Slow Left arm Orthodox

# %%
df = pd.concat([df_16, df_17, df_18, df_19, df_20, df_21, df_22 ], axis = 0)
print(df.shape)
df.head()
# Out:
# (864, 7)
#            0                 1              2                    3  \
# 0  2015/2016  Islamabad United      Amad Butt   Bowling Allrounder
# 1  2015/2016  Islamabad United     Babar Azam               Batter
# 2  2015/2016  Islamabad United  Samuel Badree               Bowler
# 3  2015/2016  Islamabad United  Sam Billings†  Wicketkeeper Batter
# 4  2015/2016  Islamabad United   Brad Haddin†  Wicketkeeper Batter
#
#                4                        5                            6
# 0  Age: 20y 226d  Batting: Right hand Bat      Bowling: Right arm Fast
# 1   Age: 21y 68d  Batting: Right hand Bat  Bowling: Right arm Offbreak
# 2  Age: 34y 288d  Batting: Right hand Bat            Bowling: Legbreak
# 3  Age: 24y 190d  Batting: Right hand Bat                         None
# 4   Age: 38y 60d  Batting: Right hand Bat                         None

# %%
df.columns = ['season', 'team', 'name', 'role', 'age', 'batting', 'bowling']
df.head()
# Out:
#       season              team           name                 role  \
# 0  2015/2016  Islamabad United      Amad Butt   Bowling Allrounder
# 1  2015/2016  Islamabad United     Babar Azam               Batter
# 2  2015/2016  Islamabad United  Samuel Badree               Bowler
# 3  2015/2016  Islamabad United  Sam Billings†  Wicketkeeper Batter
# 4  2015/2016  Islamabad United   Brad Haddin†  Wicketkeeper Batter
#
#              age                  batting                      bowling
# 0  Age: 20y 226d  Batting: Right hand Bat      Bowling: Right arm Fast
# 1   Age: 21y 68d  Batting: Right hand Bat  Bowling: Right arm Offbreak
# 2  Age: 34y 288d  Batting: Right hand Bat            Bowling: Legbreak
# 3  Age: 24y 190d  Batting: Right hand Bat                         None
# 4   Age: 38y 60d  Batting: Right hand Bat                         None

# %%
df['age'] = df['age'].str.replace('Age: ' , '')
df['batting'] = df['batting'].str.replace('Batting: ' , '')
df['bowling'] = df['bowling'].str.replace('Bowling: ' , '')
df.head()
# Out:
#       season              team           name                 role       age  \
# 0  2015/2016  Islamabad United      Amad Butt   Bowling Allrounder  20y 226d
# 1  2015/2016  Islamabad United     Babar Azam               Batter   21y 68d
# 2  2015/2016  Islamabad United  Samuel Badree               Bowler  34y 288d
# 3  2015/2016  Islamabad United  Sam Billings†  Wicketkeeper Batter  24y 190d
# 4  2015/2016  Islamabad United   Brad Haddin†  Wicketkeeper Batter   38y 60d
#
#           batting             bowling
# 0  Right hand Bat      Right arm Fast
# 1  Right hand Bat  Right arm Offbreak
# 2  Right hand Bat            Legbreak
# 3  Right hand Bat                None
# 4  Right hand Bat                None

# %%
df.groupby(['team'])['team'].count()
# Out:
# team
# Islamabad United     146
# Karachi Kings        145
# Lahore Qalandars     148
# Multan Sultans       116
# Peshawar Zalmi       163
# Quetta Gladiators    146
# Name: team, dtype: int64

# %%
df.groupby(['season'])['season'].count()
# Out:
# season
# 2015/2016     83
# 2016/2017    102
# 2017/2018    129
# 2018/2019    132
# 2019/2020    125
# 2020/2021    158
# 2021/2022    135
# Name: season, dtype: int64

# %%
df.to_csv('players.csv')
